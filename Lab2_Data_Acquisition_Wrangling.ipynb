# %% [markdown]
# <a href="https://colab.research.google.com/github/srirambtechit/workspace/blob/master/Lab2_Data_Acquisition_Wrangling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Week 2-Lab1 Data Acquisition
#
# As we start our journey into Big Data Analytics, the first thing we need to do is **get the data** in the form we need for analysis!  We'll start with an overview of how to acquire and *wrangle* data.
#
# This notebook gives us a series of examples for:
#
# * Acquiring data from files and remote sources
# * Information extraction over HTML content
# * A basic "vocabulary" of operators over tables (the relational algebra)
#
# * "Data wrangling" or integration:
#   * Cleaning and filtering data, using rules and based operations
#   * Linking data across dataframes or relations
#   * The need for approximate match and record linking

# %% [markdown]
# ## The Motivating Question
# To illustrate the principles, we focus on the question of how old company CEOs and founders are.  The question was in part motivated by the following New York Times article:
#
# * Founders of Successful Tech Companies Are Mostly Middle-Aged: https://www.nytimes.com/2019/08/29/business/tech-start-up-founders-nest.html?searchResultPosition=2
#
# So let's test this hypothesis!

# %%
# Let's install some libraries useful for processing web data

# For string similarity
# !pip3 install py_stringsimjoin

# # lxml to parse xml tree
# !pip3 install lxml
# Out:
# Collecting py_stringsimjoin
#   Downloading https://files.pythonhosted.org/packages/69/f8/343a7277ce5952a923302bb29ac547a2e3eab45965fdf40a7dd43ed058ef/py_stringsimjoin-0.3.2.tar.gz (1.1MB)
#      |████████████████████████████████| 1.1MB 4.3MB/s
# Requirement already satisfied: joblib in /usr/local/lib/python3.6/dist-packages (from py_stringsimjoin) (1.0.0)
# Requirement already satisfied: pandas>=0.16.0 in /usr/local/lib/python3.6/dist-packages (from py_stringsimjoin) (1.1.5)
# Collecting PyPrind>=2.9.3
#   Downloading https://files.pythonhosted.org/packages/1e/30/e76fb0c45da8aef49ea8d2a90d4e7a6877b45894c25f12fb961f009a891e/PyPrind-2.11.2-py3-none-any.whl
# Collecting py_stringmatching>=0.2.1
#   Downloading https://files.pythonhosted.org/packages/90/d1/9163e0b0ac3bbb0f727ef8d380985c23066fb98d5005a34483ad76da06b4/py_stringmatching-0.4.2.tar.gz (661kB)
#      |████████████████████████████████| 665kB 47.5MB/s
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from py_stringsimjoin) (1.15.0)
# Requirement already satisfied: numpy>=1.15.4 in /usr/local/lib/python3.6/dist-packages (from pandas>=0.16.0->py_stringsimjoin) (1.19.5)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.6/dist-packages (from pandas>=0.16.0->py_stringsimjoin) (2.8.1)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.6/dist-packages (from pandas>=0.16.0->py_stringsimjoin) (2018.9)
# Building wheels for collected packages: py-stringsimjoin, py-stringmatching
#   Building wheel for py-stringsimjoin (setup.py) ... done
#   Created wheel for py-stringsimjoin: filename=py_stringsimjoin-0.3.2-cp36-cp36m-linux_x86_64.whl size=3747875 sha256=5563754124523d630cc03a9624b51f3ed09941063b421bb78fcf0cbaab3bb802
#   Stored in directory: /root/.cache/pip/wheels/58/30/8e/6fa463100ff6e8595b131067ec43a118c607f621ac297e7dad
#   Building wheel for py-stringmatching (setup.py) ... done
#   Created wheel for py-stringmatching: filename=py_stringmatching-0.4.2-cp36-cp36m-linux_x86_64.whl size=2054262 sha256=f875f78371901b0bc6c3945dacb62273b72912a574b2e8fce8c242fd8132605a
#   Stored in directory: /root/.cache/pip/wheels/be/8c/5d/bcdaf17d0784738b73e856ebc4061cd3f2509753a83dd71058
# Successfully built py-stringsimjoin py-stringmatching
# Installing collected packages: PyPrind, py-stringmatching, py-stringsimjoin
# Successfully installed PyPrind-2.11.2 py-stringmatching-0.4.2 py-stringsimjoin-0.3.2
# Requirement already satisfied: lxml in /usr/local/lib/python3.6/dist-packages (4.2.6)

# %%
# Imports we'll use through the notebook, collected here for simplicity

# For parsing dates and being able to compare
import datetime

# For fetching remote data
import urllib
import urllib.request

# Pandas dataframes and operations
import pandas as pd

# Numpy matrix and array operations
import numpy as np

# Sqlite is a simplistic database
import sqlite3

# Approximate string matching, see 
import py_stringsimjoin as ssj
import py_stringmatching as sm

# Data visualization
import matplotlib

# %% [markdown]
# # Lab 1: Acquiring Data (Week 2)
#
# To test our hypothesis, we might want:
#
# 1. A list of companies (and, for futher details, perhaps their lines of business)
# 2. A list of company CEOs
# 3. Ages of the CEOs
#
# We'll go through each of these using real data from the web.
#
# ### Reading Structured Data Sources
#
# Let's start by looking up data about companies.  An example of this is at:
#
# https://gist.githubusercontent.com/jvilledieu/c3afe5bc21da28880a30/raw/a344034b82a11433ba6f149afa47e57567d4a18f/Companies.csv
#
# which has some nicely detailed information about companies, their categories, when they were founded, etc.  Let's load this (remote) CSV file into a dataframe.

# %%
data = urllib.request.urlopen(\
       'https://gist.github.com/jvilledieu/c3afe5bc21da28880a30/raw/a344034b82a11433ba6f149afa47e57567d4a18f/Companies.csv')

company_data_df = pd.read_csv(data)

# %%
# Let's write it to SQL, and read it back

conn = sqlite3.connect('local.db')

company_data_df.to_sql("companies", conn, if_exists="replace", index=False)

pd.read_sql_query('select * from companies', conn)
# Out:
#                                                 permalink  ... last_funding_at
# 0                                   /organization/waywire  ...      30/06/2012
# 1                         /organization/tv-communications  ...      23/09/2010
# 2                           /organization/rock-your-paper  ...      09/08/2012
# 3                          /organization/in-touch-network  ...      01/04/2011
# 4                                   /organization/n-plusn  ...      04/09/2014
# ...                                                   ...  ...             ...
# 47753                                 /organization/zzish  ...      24/03/2014
# 47754  /organization/zznode-science-and-technology-co-ltd  ...      01/04/2012
# 47755                           /organization/zzzzapp-com  ...      10/09/2014
# 47756                          /organization/a-list-games  ...      21/11/2011
# 47757                                     /organization/x  ...      04/04/2013
#
# [47758 rows x 18 columns]

# %% [markdown]
# ## Companies' CEOs: a Web Table
#
# Now we need to figure out who the CEOs are for corporations.  One place to look is Wikipedia, which has an HTML table describing the CEOs.
#
# https://en.wikipedia.org/wiki/List_of_chief_executive_officers#List_of_CEOs
#
# Pandas actually makes it easy to read HTML tables...

# %%
# Now let's read an HTML table!

company_ceos_df = pd.read_html('https://en.wikipedia.org/wiki/List_of_chief_executive_officers#List_of_CEOs')[0]

company_ceos_df
# Out:
#                         Company  ...  Unnamed: 7
# 0                     Accenture  ...         NaN
# 1            Aditya Birla Group  ...         NaN
# 2                 Adobe Systems  ...         NaN
# 3                        Agenus  ...         NaN
# 4                        Airbus  ...         NaN
# ..                          ...  ...         ...
# 175       Williams-Sonoma, Inc.  ...         NaN
# 176  Wipro Technologies Limited  ...         NaN
# 177                         WWE  ...         NaN
# 178                 Yum! Brands  ...         NaN
# 179                Zillow Group  ...  2020-10-12
#
# [180 rows x 8 columns]

# %% [markdown]
# ## The Problem Gets Harder... Extracting Structured Fields
#
# So far we have companies and CEOs.  But we don't have information on how old the CEOs are!
#
# For a solution, we're going to go back to Wikipedia -- this time looking at the web pages for the CEOs!
#
# This involves "crawling" the CEO pages, and "scraping" the relevant content.  In other words we have to do *information extraction*.
#
# We'll start by constructing a list of CEO web pages, from the Company CEO dataframe above.  For this, we need to take the names and do a bit of tweaking, for example adding underscores instead of spaces.

# %%
crawl_list = []

for executive in company_ceos_df['Executive']:
  crawl_list.append('https://en.wikipedia.org/wiki/' + executive.replace(' ', '_'))
 
crawl_list
# Out:
# ['https://en.wikipedia.org/wiki/Julie_Sweet',
#  'https://en.wikipedia.org/wiki/Kumar_Birla',
#  'https://en.wikipedia.org/wiki/Shantanu_Narayen',
#  'https://en.wikipedia.org/wiki/Garo_H._Armen',
#  'https://en.wikipedia.org/wiki/Guillaume_Faury',
#  'https://en.wikipedia.org/wiki/Daniel_Zhang',
#  'https://en.wikipedia.org/wiki/Jeff_Bezos',
#  'https://en.wikipedia.org/wiki/Lisa_Su',
#  'https://en.wikipedia.org/wiki/Stephen_Squeri',
#  'https://en.wikipedia.org/wiki/Doug_Parker',
#  'https://en.wikipedia.org/wiki/Joseph_R._Swedish',
#  'https://en.wikipedia.org/wiki/Tim_Cook',
#  'https://en.wikipedia.org/wiki/Lakshmi_Niwas_Mittal',
#  'https://en.wikipedia.org/wiki/John_Stankey',
#  'https://en.wikipedia.org/wiki/Charles_Woodburn',
#  'https://en.wikipedia.org/wiki/Tapan_Singhel',
#  'https://en.wikipedia.org/wiki/Carlos_Torres_Vila',
#  'https://en.wikipedia.org/wiki/Brian_Moynihan',
#  'https://en.wikipedia.org/wiki/Jes_Staley',
#  'https://en.wikipedia.org/wiki/Warren_Buffett',
#  'https://en.wikipedia.org/wiki/Hubert_Joly',
#  'https://en.wikipedia.org/wiki/Sunil_Bharti_Mittal',
#  'https://en.wikipedia.org/wiki/Stephen_A._Schwarzman',
#  'https://en.wikipedia.org/wiki/Andrew_Mackenzie',
#  'https://en.wikipedia.org/wiki/Oliver_zipse',
#  'https://en.wikipedia.org/wiki/Dave_Calhoun',
#  'https://en.wikipedia.org/wiki/Rich_Lesser',
#  'https://en.wikipedia.org/wiki/Bob_Dudley',
#  'https://en.wikipedia.org/wiki/Denise_Morrison',
#  'https://en.wikipedia.org/wiki/Mark_Shuttleworth',
#  'https://en.wikipedia.org/wiki/Paul_Hermelin',
#  'https://en.wikipedia.org/wiki/Richard_Fairbank',
#  'https://en.wikipedia.org/wiki/Jim_Umpleby',
#  'https://en.wikipedia.org/wiki/Evan_G._Greenberg',
#  'https://en.wikipedia.org/wiki/Chuck_Robbins',
#  'https://en.wikipedia.org/wiki/Michael_Corbat',
#  'https://en.wikipedia.org/wiki/James_Quincey',
#  'https://en.wikipedia.org/wiki/Brian_Humphries',
#  'https://en.wikipedia.org/wiki/Brian_L._Roberts',
#  'https://en.wikipedia.org/wiki/Tidjane_Thiam',
#  'https://en.wikipedia.org/wiki/James_E._Thompson',
#  'https://en.wikipedia.org/wiki/Ola_Källenius',
#  'https://en.wikipedia.org/wiki/Michael_Dell',
#  'https://en.wikipedia.org/wiki/Christian_Sewing',
#  'https://en.wikipedia.org/wiki/Frank_Appel',
#  'https://en.wikipedia.org/wiki/Roland_Dickey_Jr.',
#  'https://en.wikipedia.org/wiki/Edward_D._Breen',
#  'https://en.wikipedia.org/wiki/G._V._Prasad',
#  'https://en.wikipedia.org/wiki/Jeff_Clarke',
#  'https://en.wikipedia.org/wiki/Devin_Wenig',
#  'https://en.wikipedia.org/wiki/Andrew_Wilson',
#  'https://en.wikipedia.org/wiki/Börje_Ekholm',
#  'https://en.wikipedia.org/wiki/Darren_Woods',
#  'https://en.wikipedia.org/wiki/Carmine_Di_Sibio',
#  'https://en.wikipedia.org/wiki/Mark_Zuckerberg',
#  'https://en.wikipedia.org/wiki/Frederick_W._Smith',
#  'https://en.wikipedia.org/wiki/Sergio_Marchionne',
#  'https://en.wikipedia.org/wiki/Abigail_Johnson',
#  'https://en.wikipedia.org/wiki/James_Hackett',
#  'https://en.wikipedia.org/wiki/Terry_Gou',
#  'https://en.wikipedia.org/wiki/Lachlan_Murdoch',
#  'https://en.wikipedia.org/wiki/Daymond_John',
#  'https://en.wikipedia.org/wiki/Phebe_Novakovic',
#  'https://en.wikipedia.org/wiki/H._Lawrence_Culp_Jr.',
#  'https://en.wikipedia.org/wiki/Mary_T._Barra',
#  'https://en.wikipedia.org/wiki/Emma_Walmsley',
#  'https://en.wikipedia.org/wiki/David_M._Solomon',
#  'https://en.wikipedia.org/wiki/Sundar_Pichai',
#  'https://en.wikipedia.org/wiki/Felipe_Gozon',
#  'https://en.wikipedia.org/wiki/Gunupati_Venkata_Krishna_Reddy',
#  'https://en.wikipedia.org/wiki/C_Vijayakumar',
#  'https://en.wikipedia.org/wiki/Lee_Shau_Kee',
#  'https://en.wikipedia.org/wiki/Meg_Whitman',
#  'https://en.wikipedia.org/wiki/Darius_Adamczyk',
#  'https://en.wikipedia.org/wiki/John_A._Kaneb',
#  'https://en.wikipedia.org/wiki/Noel_Quinn',
#  'https://en.wikipedia.org/wiki/Arvind_Krishna',
#  'https://en.wikipedia.org/wiki/Dikesh_Malhotra',
#  'https://en.wikipedia.org/wiki/Salil_Parekh',
#  'https://en.wikipedia.org/wiki/Robert_H._Swan',
#  'https://en.wikipedia.org/wiki/Scott_Etzler',
#  'https://en.wikipedia.org/wiki/Millard_Drexler',
#  'https://en.wikipedia.org/wiki/Richard_B._Handler',
#  'https://en.wikipedia.org/wiki/James_Dimon',
#  'https://en.wikipedia.org/wiki/Andrew_S._Rosen',
#  'https://en.wikipedia.org/wiki/Pieter_Elbers',
#  'https://en.wikipedia.org/wiki/Charles_G._Koch',
#  'https://en.wikipedia.org/wiki/Robert_Noel',
#  'https://en.wikipedia.org/wiki/Sheldon_Adelson',
#  'https://en.wikipedia.org/wiki/Les_Wexner',
#  'https://en.wikipedia.org/wiki/Marillyn_Hewson',
#  'https://en.wikipedia.org/wiki/Steve_Rowe',
#  'https://en.wikipedia.org/wiki/Ajaypal_Singh_Banga',
#  'https://en.wikipedia.org/wiki/Chris_kempczinski',
#  'https://en.wikipedia.org/wiki/Kevin_Sneader',
#  'https://en.wikipedia.org/wiki/Jonathan_Ornstein',
#  'https://en.wikipedia.org/wiki/Steven_A._Kandarian',
#  'https://en.wikipedia.org/wiki/Isaac_Larian',
#  'https://en.wikipedia.org/wiki/Satya_Nadella',
#  'https://en.wikipedia.org/wiki/Michael_J._Saylor',
#  'https://en.wikipedia.org/wiki/James_P._Gorman',
#  'https://en.wikipedia.org/wiki/Toxey_Haas',
#  'https://en.wikipedia.org/wiki/Chris_Beard',
#  'https://en.wikipedia.org/wiki/Sumner_Redstone',
#  'https://en.wikipedia.org/wiki/Jeff_Shell',
#  'https://en.wikipedia.org/wiki/Robert_James_Thomson',
#  'https://en.wikipedia.org/wiki/Mark_Thompson',
#  'https://en.wikipedia.org/wiki/Vijay_K._Thadani',
#  'https://en.wikipedia.org/wiki/Mark_Parker',
#  'https://en.wikipedia.org/wiki/Pekka_Lundmark',
#  'https://en.wikipedia.org/wiki/Vasant_Narasimhan',
#  'https://en.wikipedia.org/wiki/Tatsumi_Kimishima',
#  'https://en.wikipedia.org/wiki/Tim_Armstrong',
#  'https://en.wikipedia.org/wiki/Safra_Catz',
#  'https://en.wikipedia.org/wiki/Mark_Hurd',
#  'https://en.wikipedia.org/wiki/Ramon_Laguarta',
#  'https://en.wikipedia.org/wiki/Ian_Read',
#  'https://en.wikipedia.org/wiki/Patrice_Louvet',
#  'https://en.wikipedia.org/wiki/David_S._Taylor',
#  'https://en.wikipedia.org/wiki/John_Strangfeld',
#  'https://en.wikipedia.org/wiki/Alan_Joyce',
#  'https://en.wikipedia.org/wiki/Anil_Ambani',
#  'https://en.wikipedia.org/wiki/Mukesh_Ambani',
#  'https://en.wikipedia.org/wiki/Luca_de_Meo',
#  'https://en.wikipedia.org/wiki/Phiwa_Nkambule',
#  'https://en.wikipedia.org/wiki/David_I._McKay',
#  'https://en.wikipedia.org/wiki/Ross_McEwan',
#  'https://en.wikipedia.org/wiki/Ben_van_Beurden',
#  "https://en.wikipedia.org/wiki/Michael_O'Leary",
#  'https://en.wikipedia.org/wiki/Douglas_L._Peterson',
#  'https://en.wikipedia.org/wiki/Herbert_Fisk_Johnson_III',
#  'https://en.wikipedia.org/wiki/Brian_Peddle',
#  'https://en.wikipedia.org/wiki/Oh-Hyun_Kwon',
#  'https://en.wikipedia.org/wiki/Christian_Klein',
#  'https://en.wikipedia.org/wiki/James_Goodnight',
#  'https://en.wikipedia.org/wiki/Jean-Pascal_Tricoire',
#  'https://en.wikipedia.org/wiki/Joe_Kaeser',
#  'https://en.wikipedia.org/wiki/David_Simon',
#  'https://en.wikipedia.org/wiki/Chua_Sock_Koong',
#  'https://en.wikipedia.org/wiki/Masayoshi_Son',
#  'https://en.wikipedia.org/wiki/Tony_Aquila',
#  'https://en.wikipedia.org/wiki/Gary_C._Kelly',
#  'https://en.wikipedia.org/wiki/J._Clifford_Hudson',
#  'https://en.wikipedia.org/wiki/Kevin_Johnson',
#  'https://en.wikipedia.org/wiki/Raymond_Kwok',
#  'https://en.wikipedia.org/wiki/Dilip_Shanghvi',
#  'https://en.wikipedia.org/wiki/William_H._Rogers_Jr.',
#  'https://en.wikipedia.org/wiki/Rakesh_Khanna',
#  'https://en.wikipedia.org/wiki/Brian_Cornell',
#  'https://en.wikipedia.org/wiki/Rajesh_Gopinathan',
#  'https://en.wikipedia.org/wiki/Li_Dongsheng',
#  'https://en.wikipedia.org/wiki/Andy_Penn',
#  'https://en.wikipedia.org/wiki/Ho_Ching',
#  'https://en.wikipedia.org/wiki/Dave_Lewis',
#  'https://en.wikipedia.org/wiki/Elon_Musk',
#  'https://en.wikipedia.org/wiki/Diego_Della_Valle',
#  'https://en.wikipedia.org/wiki/Alan_D._Schnitzer',
#  'https://en.wikipedia.org/wiki/Akio_Toyoda',
#  'https://en.wikipedia.org/wiki/Bill_Stromberg',
#  'https://en.wikipedia.org/wiki/Jack_Dorsey',
#  'https://en.wikipedia.org/wiki/Oscar_Munoz',
#  'https://en.wikipedia.org/wiki/ralph_hamers',
#  'https://en.wikipedia.org/wiki/Joseph_C._Papa',
#  'https://en.wikipedia.org/wiki/Hans_Vestberg',
#  'https://en.wikipedia.org/wiki/Robert_Bakish',
#  'https://en.wikipedia.org/wiki/Vittorio_Colao',
#  'https://en.wikipedia.org/wiki/Herbert_Diess',
#  'https://en.wikipedia.org/wiki/Bill_Hilf',
#  'https://en.wikipedia.org/wiki/Bob_Chapek',
#  'https://en.wikipedia.org/wiki/Stefano_Pessina',
#  'https://en.wikipedia.org/wiki/Doug_McMillon',
#  'https://en.wikipedia.org/wiki/Ann_Sarnoff',
#  'https://en.wikipedia.org/wiki/Jason_Kilar',
#  'https://en.wikipedia.org/wiki/Timothy_J._Sloan',
#  'https://en.wikipedia.org/wiki/John_Mackey',
#  'https://en.wikipedia.org/wiki/Laura_J._Alber',
#  'https://en.wikipedia.org/wiki/Abidali_Neemuchwala',
#  'https://en.wikipedia.org/wiki/Vince_McMahon',
#  'https://en.wikipedia.org/wiki/Greg_Creed',
#  'https://en.wikipedia.org/wiki/Rich_Barton']

# %%
# Use urllib.urlopen to crawl all pages in crawl_list, and store the response of the page
# in list pages 

pages = []

for url in crawl_list:
    page = url.split("/")[-1] #extract the person name at the end of the url
    print('Looking at file %s' % page)

    # An issue: some of the accent characters won't work.  We need to convert them
    # into an HTML URL.  We'll split the URL, then use "parse.quote" to change
    # the structure, then re-form the URL
    url_list = list(urllib.parse.urlsplit(url))
    url_list[2] = urllib.parse.quote(url_list[2])
    url_ascii = urllib.parse.urlunsplit(url_list)
    try:
      response = urllib.request.urlopen((url_ascii))
      #Save page and url for later use.
      pages.append(response)
    except urllib.error.URLError as e:
      print(e.reason)
# Out:
# Looking at file Julie_Sweet
# Looking at file Kumar_Birla
# Looking at file Shantanu_Narayen
# Looking at file Garo_H._Armen
# Looking at file Guillaume_Faury
# Looking at file Daniel_Zhang
# Looking at file Jeff_Bezos
# Looking at file Lisa_Su
# Looking at file Stephen_Squeri
# Looking at file Doug_Parker
# Looking at file Joseph_R._Swedish
# Looking at file Tim_Cook
# Looking at file Lakshmi_Niwas_Mittal
# Looking at file John_Stankey
# Looking at file Charles_Woodburn
# Looking at file Tapan_Singhel
# Looking at file Carlos_Torres_Vila
# Looking at file Brian_Moynihan
# Looking at file Jes_Staley
# Looking at file Warren_Buffett
# Looking at file Hubert_Joly
# Looking at file Sunil_Bharti_Mittal
# Looking at file Stephen_A._Schwarzman
# Looking at file Andrew_Mackenzie
# Looking at file Oliver_zipse
# Not Found
# Looking at file Dave_Calhoun
# Looking at file Rich_Lesser
# Looking at file Bob_Dudley
# Looking at file Denise_Morrison
# Looking at file Mark_Shuttleworth
# Looking at file Paul_Hermelin
# Looking at file Richard_Fairbank
# Looking at file Jim_Umpleby
# Looking at file Evan_G._Greenberg
# Looking at file Chuck_Robbins
# Looking at file Michael_Corbat
# Looking at file James_Quincey
# Looking at file Brian_Humphries
# Looking at file Brian_L._Roberts
# Looking at file Tidjane_Thiam
# Looking at file James_E._Thompson
# Looking at file Ola_Källenius
# Looking at file Michael_Dell
# Looking at file Christian_Sewing
# Looking at file Frank_Appel
# Looking at file Roland_Dickey_Jr.
# Looking at file Edward_D._Breen
# Looking at file G._V._Prasad
# Looking at file Jeff_Clarke
# Looking at file Devin_Wenig
# Looking at file Andrew_Wilson
# Looking at file Börje_Ekholm
# Looking at file Darren_Woods
# Looking at file Carmine_Di_Sibio
# Looking at file Mark_Zuckerberg
# Looking at file Frederick_W._Smith
# Looking at file Sergio_Marchionne
# Looking at file Abigail_Johnson
# Looking at file James_Hackett
# Looking at file Terry_Gou
# Looking at file Lachlan_Murdoch
# Looking at file Daymond_John
# Looking at file Phebe_Novakovic
# Looking at file H._Lawrence_Culp_Jr.
# Looking at file Mary_T._Barra
# Looking at file Emma_Walmsley
# Looking at file David_M._Solomon
# Looking at file Sundar_Pichai
# Looking at file Felipe_Gozon
# Looking at file Gunupati_Venkata_Krishna_Reddy
# Looking at file C_Vijayakumar
# Looking at file Lee_Shau_Kee
# Looking at file Meg_Whitman
# Looking at file Darius_Adamczyk
# Looking at file John_A._Kaneb
# Looking at file Noel_Quinn
# Looking at file Arvind_Krishna
# Looking at file Dikesh_Malhotra
# Looking at file Salil_Parekh
# Looking at file Robert_H._Swan
# Looking at file Scott_Etzler
# Looking at file Millard_Drexler
# Looking at file Richard_B._Handler
# Looking at file James_Dimon
# Looking at file Andrew_S._Rosen
# Looking at file Pieter_Elbers
# Looking at file Charles_G._Koch
# Looking at file Robert_Noel
# Looking at file Sheldon_Adelson
# Looking at file Les_Wexner
# Looking at file Marillyn_Hewson
# Looking at file Steve_Rowe
# Looking at file Ajaypal_Singh_Banga
# Looking at file Chris_kempczinski
# Not Found
# Looking at file Kevin_Sneader
# Looking at file Jonathan_Ornstein
# Looking at file Steven_A._Kandarian
# Looking at file Isaac_Larian
# Looking at file Satya_Nadella
# Looking at file Michael_J._Saylor
# Looking at file James_P._Gorman
# Looking at file Toxey_Haas
# Looking at file Chris_Beard
# Looking at file Sumner_Redstone
# Looking at file Jeff_Shell
# Looking at file Robert_James_Thomson
# Looking at file Mark_Thompson
# Looking at file Vijay_K._Thadani
# Looking at file Mark_Parker
# Looking at file Pekka_Lundmark
# Looking at file Vasant_Narasimhan
# Looking at file Tatsumi_Kimishima
# Looking at file Tim_Armstrong
# Looking at file Safra_Catz
# Looking at file Mark_Hurd
# Looking at file Ramon_Laguarta
# Looking at file Ian_Read
# Looking at file Patrice_Louvet
# Looking at file David_S._Taylor
# Looking at file John_Strangfeld
# Looking at file Alan_Joyce
# Looking at file Anil_Ambani
# Looking at file Mukesh_Ambani
# Looking at file Luca_de_Meo
# Looking at file Phiwa_Nkambule
# Looking at file David_I._McKay
# Looking at file Ross_McEwan
# Looking at file Ben_van_Beurden
# Looking at file Michael_O'Leary
# Looking at file Douglas_L._Peterson
# Looking at file Herbert_Fisk_Johnson_III
# Looking at file Brian_Peddle
# Looking at file Oh-Hyun_Kwon
# Looking at file Christian_Klein
# Looking at file James_Goodnight
# Looking at file Jean-Pascal_Tricoire
# Looking at file Joe_Kaeser
# Looking at file David_Simon
# Looking at file Chua_Sock_Koong
# Looking at file Masayoshi_Son
# Looking at file Tony_Aquila
# Looking at file Gary_C._Kelly
# Looking at file J._Clifford_Hudson
# Looking at file Kevin_Johnson
# Looking at file Raymond_Kwok
# Looking at file Dilip_Shanghvi
# Looking at file William_H._Rogers_Jr.
# Looking at file Rakesh_Khanna
# Looking at file Brian_Cornell
# Looking at file Rajesh_Gopinathan
# Looking at file Li_Dongsheng
# Looking at file Andy_Penn
# Looking at file Ho_Ching
# Looking at file Dave_Lewis
# Looking at file Elon_Musk
# Looking at file Diego_Della_Valle
# Looking at file Alan_D._Schnitzer
# Looking at file Akio_Toyoda
# Looking at file Bill_Stromberg
# Looking at file Jack_Dorsey
# Looking at file Oscar_Munoz
# Looking at file ralph_hamers
# Not Found
# Looking at file Joseph_C._Papa
# Looking at file Hans_Vestberg
# Looking at file Robert_Bakish
# Looking at file Vittorio_Colao
# Looking at file Herbert_Diess
# Looking at file Bill_Hilf
# Looking at file Bob_Chapek
# Looking at file Stefano_Pessina
# Looking at file Doug_McMillon
# Looking at file Ann_Sarnoff
# Looking at file Jason_Kilar
# Looking at file Timothy_J._Sloan
# Looking at file John_Mackey
# Looking at file Laura_J._Alber
# Looking at file Abidali_Neemuchwala
# Looking at file Vince_McMahon
# Looking at file Greg_Creed
# Looking at file Rich_Barton

# %%
pages
# Out:
# [<http.client.HTTPResponse at 0x7f437726cbe0>,
#  <http.client.HTTPResponse at 0x7f437746e400>,
#  <http.client.HTTPResponse at 0x7f4377605550>,
#  <http.client.HTTPResponse at 0x7f437746e5f8>,
#  <http.client.HTTPResponse at 0x7f4377487e80>,
#  <http.client.HTTPResponse at 0x7f43774875c0>,
#  <http.client.HTTPResponse at 0x7f4377373ac8>,
#  <http.client.HTTPResponse at 0x7f4376e16be0>,
#  <http.client.HTTPResponse at 0x7f4376e16cc0>,
#  <http.client.HTTPResponse at 0x7f4376e16e48>,
#  <http.client.HTTPResponse at 0x7f4376d7dc88>,
#  <http.client.HTTPResponse at 0x7f4376d7d550>,
#  <http.client.HTTPResponse at 0x7f4376d7da58>,
#  <http.client.HTTPResponse at 0x7f4376d7df98>,
#  <http.client.HTTPResponse at 0x7f4376c9d2e8>,
#  <http.client.HTTPResponse at 0x7f4376c9d710>,
#  <http.client.HTTPResponse at 0x7f437746ea20>,
#  <http.client.HTTPResponse at 0x7f4376e16ef0>,
#  <http.client.HTTPResponse at 0x7f4376c9dc88>,
#  <http.client.HTTPResponse at 0x7f4376d7dac8>,
#  <http.client.HTTPResponse at 0x7f4376cb6940>,
#  <http.client.HTTPResponse at 0x7f4376cb6e48>,
#  <http.client.HTTPResponse at 0x7f4376cc3160>,
#  <http.client.HTTPResponse at 0x7f4376cc3630>,
#  <http.client.HTTPResponse at 0x7f4376cc3f60>,
#  <http.client.HTTPResponse at 0x7f4376cc3ef0>,
#  <http.client.HTTPResponse at 0x7f4376c2c320>,
#  <http.client.HTTPResponse at 0x7f4376c2c780>,
#  <http.client.HTTPResponse at 0x7f4376c2ccc0>,
#  <http.client.HTTPResponse at 0x7f4376c377f0>,
#  <http.client.HTTPResponse at 0x7f4376c37518>,
#  <http.client.HTTPResponse at 0x7f4376c37a20>,
#  <http.client.HTTPResponse at 0x7f4376c37ef0>,
#  <http.client.HTTPResponse at 0x7f4376b9add8>,
#  <http.client.HTTPResponse at 0x7f4376b9a6a0>,
#  <http.client.HTTPResponse at 0x7f4376cb6dd8>,
#  <http.client.HTTPResponse at 0x7f4377373160>,
#  <http.client.HTTPResponse at 0x7f4376b9a710>,
#  <http.client.HTTPResponse at 0x7f4376bb7f60>,
#  <http.client.HTTPResponse at 0x7f4376bb7828>,
#  <http.client.HTTPResponse at 0x7f4376bb7be0>,
#  <http.client.HTTPResponse at 0x7f4376b6b208>,
#  <http.client.HTTPResponse at 0x7f4376b6b6a0>,
#  <http.client.HTTPResponse at 0x7f4376b6bba8>,
#  <http.client.HTTPResponse at 0x7f4376b6b588>,
#  <http.client.HTTPResponse at 0x7f4376b7f048>,
#  <http.client.HTTPResponse at 0x7f4376b7f7f0>,
#  <http.client.HTTPResponse at 0x7f4376b7fcf8>,
#  <http.client.HTTPResponse at 0x7f4376b1a828>,
#  <http.client.HTTPResponse at 0x7f4376b1a550>,
#  <http.client.HTTPResponse at 0x7f4376b1ab00>,
#  <http.client.HTTPResponse at 0x7f4376b1a198>,
#  <http.client.HTTPResponse at 0x7f4376b43358>,
#  <http.client.HTTPResponse at 0x7f4376c2cc88>,
#  <http.client.HTTPResponse at 0x7f4376cc3b00>,
#  <http.client.HTTPResponse at 0x7f4376b43d68>,
#  <http.client.HTTPResponse at 0x7f4376bb7d30>,
#  <http.client.HTTPResponse at 0x7f4376ab1080>,
#  <http.client.HTTPResponse at 0x7f4376ab18d0>,
#  <http.client.HTTPResponse at 0x7f4376ab1dd8>,
#  <http.client.HTTPResponse at 0x7f4376ac88d0>,
#  <http.client.HTTPResponse at 0x7f4376ac8630>,
#  <http.client.HTTPResponse at 0x7f4376ac8b00>,
#  <http.client.HTTPResponse at 0x7f4376ac8198>,
#  <http.client.HTTPResponse at 0x7f4376999a90>,
#  <http.client.HTTPResponse at 0x7f43769997f0>,
#  <http.client.HTTPResponse at 0x7f4376999cc0>,
#  <http.client.HTTPResponse at 0x7f43769c8c50>,
#  <http.client.HTTPResponse at 0x7f43769c8550>,
#  <http.client.HTTPResponse at 0x7f43769c8a20>,
#  <http.client.HTTPResponse at 0x7f43769c8f28>,
#  <http.client.HTTPResponse at 0x7f437692f9b0>,
#  <http.client.HTTPResponse at 0x7f437692f6d8>,
#  <http.client.HTTPResponse at 0x7f4376bb7cf8>,
#  <http.client.HTTPResponse at 0x7f4376c37f60>,
#  <http.client.HTTPResponse at 0x7f437692fb70>,
#  <http.client.HTTPResponse at 0x7f4376816b38>,
#  <http.client.HTTPResponse at 0x7f4376816860>,
#  <http.client.HTTPResponse at 0x7f4376816d30>,
#  <http.client.HTTPResponse at 0x7f4376838860>,
#  <http.client.HTTPResponse at 0x7f4376838588>,
#  <http.client.HTTPResponse at 0x7f4376838a90>,
#  <http.client.HTTPResponse at 0x7f4376838f98>,
#  <http.client.HTTPResponse at 0x7f437672fe80>,
#  <http.client.HTTPResponse at 0x7f437672f748>,
#  <http.client.HTTPResponse at 0x7f437672fc50>,
#  <http.client.HTTPResponse at 0x7f43766d3048>,
#  <http.client.HTTPResponse at 0x7f43766d3518>,
#  <http.client.HTTPResponse at 0x7f43766d39b0>,
#  <http.client.HTTPResponse at 0x7f43766d3ef0>,
#  <http.client.HTTPResponse at 0x7f43766f5198>,
#  <http.client.HTTPResponse at 0x7f43766f5668>,
#  <http.client.HTTPResponse at 0x7f4376816cf8>,
#  <http.client.HTTPResponse at 0x7f4376ac89b0>,
#  <http.client.HTTPResponse at 0x7f43766f5ba8>,
#  <http.client.HTTPResponse at 0x7f43766a0f28>,
#  <http.client.HTTPResponse at 0x7f43766a0710>,
#  <http.client.HTTPResponse at 0x7f43766a0d30>,
#  <http.client.HTTPResponse at 0x7f437661d0f0>,
#  <http.client.HTTPResponse at 0x7f437661d550>,
#  <http.client.HTTPResponse at 0x7f437661da58>,
#  <http.client.HTTPResponse at 0x7f437661df60>,
#  <http.client.HTTPResponse at 0x7f437650f9e8>,
#  <http.client.HTTPResponse at 0x7f437650f748>,
#  <http.client.HTTPResponse at 0x7f437650fc18>,
#  <http.client.HTTPResponse at 0x7f437651fba8>,
#  <http.client.HTTPResponse at 0x7f437651f470>,
#  <http.client.HTTPResponse at 0x7f437651f978>,
#  <http.client.HTTPResponse at 0x7f437651fe80>,
#  <http.client.HTTPResponse at 0x7f4376540d68>,
#  <http.client.HTTPResponse at 0x7f4376540630>,
#  <http.client.HTTPResponse at 0x7f4376540b38>,
#  <http.client.HTTPResponse at 0x7f4376816f98>,
#  <http.client.HTTPResponse at 0x7f4376838cc0>,
#  <http.client.HTTPResponse at 0x7f4376540ba8>,
#  <http.client.HTTPResponse at 0x7f43763ff780>,
#  <http.client.HTTPResponse at 0x7f43763ffc88>,
#  <http.client.HTTPResponse at 0x7f43763adbe0>,
#  <http.client.HTTPResponse at 0x7f43763ad4a8>,
#  <http.client.HTTPResponse at 0x7f43763ad9b0>,
#  <http.client.HTTPResponse at 0x7f43763adeb8>,
#  <http.client.HTTPResponse at 0x7f43762d1208>,
#  <http.client.HTTPResponse at 0x7f43762d1668>,
#  <http.client.HTTPResponse at 0x7f43762d1b70>,
#  <http.client.HTTPResponse at 0x7f43762d1a20>,
#  <http.client.HTTPResponse at 0x7f43762f53c8>,
#  <http.client.HTTPResponse at 0x7f43762f5940>,
#  <http.client.HTTPResponse at 0x7f43762f5e10>,
#  <http.client.HTTPResponse at 0x7f4376299128>,
#  <http.client.HTTPResponse at 0x7f43762995f8>,
#  <http.client.HTTPResponse at 0x7f4376299b00>,
#  <http.client.HTTPResponse at 0x7f43766a0828>,
#  <http.client.HTTPResponse at 0x7f43762f5828>,
#  <http.client.HTTPResponse at 0x7f43762ca710>,
#  <http.client.HTTPResponse at 0x7f43762cab00>,
#  <http.client.HTTPResponse at 0x7f43762cad30>,
#  <http.client.HTTPResponse at 0x7f4376208c18>,
#  <http.client.HTTPResponse at 0x7f43762084e0>,
#  <http.client.HTTPResponse at 0x7f43762089e8>,
#  <http.client.HTTPResponse at 0x7f4376208f28>,
#  <http.client.HTTPResponse at 0x7f437611d208>,
#  <http.client.HTTPResponse at 0x7f437611d6a0>,
#  <http.client.HTTPResponse at 0x7f437611dba8>,
#  <http.client.HTTPResponse at 0x7f437611dcc0>,
#  <http.client.HTTPResponse at 0x7f4376149470>,
#  <http.client.HTTPResponse at 0x7f4376149898>,
#  <http.client.HTTPResponse at 0x7f4376149da0>,
#  <http.client.HTTPResponse at 0x7f43760f7860>,
#  <http.client.HTTPResponse at 0x7f43760f7588>,
#  <http.client.HTTPResponse at 0x7f43760f7a90>,
#  <http.client.HTTPResponse at 0x7f43760f7f98>,
#  <http.client.HTTPResponse at 0x7f4376cc3a20>,
#  <http.client.HTTPResponse at 0x7f43760f7f60>,
#  <http.client.HTTPResponse at 0x7f4376149860>,
#  <http.client.HTTPResponse at 0x7f437605cc88>,
#  <http.client.HTTPResponse at 0x7f4375f9e780>,
#  <http.client.HTTPResponse at 0x7f4375f9e4a8>,
#  <http.client.HTTPResponse at 0x7f4375f9e9b0>,
#  <http.client.HTTPResponse at 0x7f4375f9eeb8>,
#  <http.client.HTTPResponse at 0x7f4375fbab38>,
#  <http.client.HTTPResponse at 0x7f4375fbacf8>,
#  <http.client.HTTPResponse at 0x7f4375fba9e8>,
#  <http.client.HTTPResponse at 0x7f4375fbab70>,
#  <http.client.HTTPResponse at 0x7f4375ee7160>,
#  <http.client.HTTPResponse at 0x7f4375ee7908>,
#  <http.client.HTTPResponse at 0x7f4375ee7e10>,
#  <http.client.HTTPResponse at 0x7f4375f02d30>,
#  <http.client.HTTPResponse at 0x7f4375f02630>,
#  <http.client.HTTPResponse at 0x7f43762ca828>,
#  <http.client.HTTPResponse at 0x7f4375ee78d0>,
#  <http.client.HTTPResponse at 0x7f4375fbaba8>,
#  <http.client.HTTPResponse at 0x7f43786aca58>,
#  <http.client.HTTPResponse at 0x7f43786ac780>,
#  <http.client.HTTPResponse at 0x7f43786acc50>,
#  <http.client.HTTPResponse at 0x7f437858f780>,
#  <http.client.HTTPResponse at 0x7f437858f4a8>,
#  <http.client.HTTPResponse at 0x7f437858f9e8>]

# %% [markdown]
# ## Populating the Table with Executives

# %%
# Use lxml.etree.HTML(...) on the HTML content of each page to get a DOM tree that
# can be processed via XPath to extract the bday information.  Store the CEO name, 
# webpage, and the birthdate (born) in exec_df.

# We first check that the HTML content has a table of type `vcard`,
# and then extract the `bday` information.  If there is no birthdate, the datetime 
# value is NaT (not a type). 

from lxml import etree

exec_df = pd.DataFrame(columns=['name','page','born'])

for page in pages:    
    tree = etree.HTML(page.read().decode("utf-8"))  #create a DOM tree of the page
    url = page.geturl()
    bday = tree.xpath('//table[contains(@class,"vcard")]//span[@class="bday"]/text()')
    if len(bday) > 0:
        name = url[url.rfind('/')+1:] # The part of the URL after the last /
        exec_df = exec_df.append({'name': name, 'page': url,
                   'born': datetime.datetime.strptime(bday[0], '%Y-%m-%d')}, ignore_index=True)
    else: 
            exec_df = exec_df.append({'name': url[url.rfind('/')+1:], 'page': url
                                      , 'born': None}, ignore_index=True)
        
exec_df
# Out:
#                     name  ...       born
# 0            Julie_Sweet  ...        NaT
# 1            Kumar_Birla  ... 1967-06-14
# 2       Shantanu_Narayen  ... 1963-05-27
# 3          Garo_H._Armen  ... 1953-01-31
# 4        Guillaume_Faury  ... 1968-02-22
# ..                   ...  ...        ...
# 172       Laura_J._Alber  ...        NaT
# 173  Abidali_Neemuchwala  ...        NaT
# 174        Vince_McMahon  ... 1945-08-24
# 175           Greg_Creed  ...        NaT
# 176          Rich_Barton  ...        NaT
#
# [177 rows x 3 columns]

# %% [markdown]
# # Lab 2- week 3 : Data Transformation
#
# Looking at our data to clean via *projection*...
#
# Generally, we can extract one "narrower" table form another by using **double brackets**.

# %%
# Let's take a look at the data.  Here's a way of PROJECTING the exec_df dataframe into
# a smaller table

exec_df[['name', 'born']]
# Out:
#                     name       born
# 0            Julie_Sweet        NaT
# 1            Kumar_Birla 1967-06-14
# 2       Shantanu_Narayen 1963-05-27
# 3          Garo_H._Armen 1953-01-31
# 4        Guillaume_Faury 1968-02-22
# ..                   ...        ...
# 172       Laura_J._Alber        NaT
# 173  Abidali_Neemuchwala        NaT
# 174        Vince_McMahon 1945-08-24
# 175           Greg_Creed        NaT
# 176          Rich_Barton        NaT
#
# [177 rows x 2 columns]

# %%
# If I use single brackets, I can extract a single column as a Series.
exec_df['name']
# Out:
# 0              Julie_Sweet
# 1              Kumar_Birla
# 2         Shantanu_Narayen
# 3            Garo_H._Armen
# 4          Guillaume_Faury
#               ...
# 172         Laura_J._Alber
# 173    Abidali_Neemuchwala
# 174          Vince_McMahon
# 175             Greg_Creed
# 176            Rich_Barton
# Name: name, Length: 177, dtype: object

# %%
# Notice anything awry?

for person in exec_df['name']:
    print (person)
# Out:
# Julie_Sweet
# Kumar_Birla
# Shantanu_Narayen
# Garo_H._Armen
# Guillaume_Faury
# Daniel_Zhang
# Jeff_Bezos
# Lisa_Su
# Stephen_Squeri
# Doug_Parker
# Joseph_R._Swedish
# Tim_Cook
# Lakshmi_Niwas_Mittal
# John_Stankey
# Charles_Woodburn
# Tapan_Singhel
# Carlos_Torres_Vila
# Brian_Moynihan
# Jes_Staley
# Warren_Buffett
# Hubert_Joly
# Sunil_Bharti_Mittal
# Stephen_A._Schwarzman
# Andrew_Mackenzie
# Dave_Calhoun
# Rich_Lesser
# Bob_Dudley
# Denise_Morrison
# Mark_Shuttleworth
# Paul_Hermelin
# Richard_Fairbank
# Jim_Umpleby
# Evan_G._Greenberg
# Chuck_Robbins
# Michael_Corbat
# James_Quincey
# Brian_Humphries
# Brian_L._Roberts
# Tidjane_Thiam
# James_E._Thompson
# Ola_K%C3%A4llenius
# Michael_Dell
# Christian_Sewing
# Frank_Appel
# Roland_Dickey_Jr.
# Edward_D._Breen
# G._V._Prasad
# Jeff_Clarke
# Devin_Wenig
# Andrew_Wilson
# B%C3%B6rje_Ekholm
# Darren_Woods
# Carmine_Di_Sibio
# Mark_Zuckerberg
# Frederick_W._Smith
# Sergio_Marchionne
# Abigail_Johnson
# James_Hackett
# Terry_Gou
# Lachlan_Murdoch
# Daymond_John
# Phebe_Novakovic
# H._Lawrence_Culp_Jr.
# Mary_T._Barra
# Emma_Walmsley
# David_M._Solomon
# Sundar_Pichai
# Felipe_Gozon
# Gunupati_Venkata_Krishna_Reddy
# C_Vijayakumar
# Lee_Shau_Kee
# Meg_Whitman
# Darius_Adamczyk
# John_A._Kaneb
# Noel_Quinn
# Arvind_Krishna
# Dikesh_Malhotra
# Salil_Parekh
# Robert_H._Swan
# Scott_Etzler
# Millard_Drexler
# Richard_B._Handler
# James_Dimon
# Andrew_S._Rosen
# Pieter_Elbers
# Charles_G._Koch
# Robert_Noel
# Sheldon_Adelson
# Les_Wexner
# Marillyn_Hewson
# Steve_Rowe
# Ajaypal_Singh_Banga
# Kevin_Sneader
# Jonathan_Ornstein
# Steven_A._Kandarian
# Isaac_Larian
# Satya_Nadella
# Michael_J._Saylor
# James_P._Gorman
# Toxey_Haas
# Chris_Beard
# Sumner_Redstone
# Jeff_Shell
# Robert_James_Thomson
# Mark_Thompson
# Vijay_K._Thadani
# Mark_Parker
# Pekka_Lundmark
# Vasant_Narasimhan
# Tatsumi_Kimishima
# Tim_Armstrong
# Safra_Catz
# Mark_Hurd
# Ramon_Laguarta
# Ian_Read
# Patrice_Louvet
# David_S._Taylor
# John_Strangfeld
# Alan_Joyce
# Anil_Ambani
# Mukesh_Ambani
# Luca_de_Meo
# Phiwa_Nkambule
# David_I._McKay
# Ross_McEwan
# Ben_van_Beurden
# Michael_O%27Leary
# Douglas_L._Peterson
# Herbert_Fisk_Johnson_III
# Brian_Peddle
# Oh-Hyun_Kwon
# Christian_Klein
# James_Goodnight
# Jean-Pascal_Tricoire
# Joe_Kaeser
# David_Simon
# Chua_Sock_Koong
# Masayoshi_Son
# Tony_Aquila
# Gary_C._Kelly
# J._Clifford_Hudson
# Kevin_Johnson
# Raymond_Kwok
# Dilip_Shanghvi
# William_H._Rogers_Jr.
# Rakesh_Khanna
# Brian_Cornell
# Rajesh_Gopinathan
# Li_Dongsheng
# Andy_Penn
# Ho_Ching
# Dave_Lewis
# Elon_Musk
# Diego_Della_Valle
# Alan_D._Schnitzer
# Akio_Toyoda
# Bill_Stromberg
# Jack_Dorsey
# Oscar_Munoz
# Joseph_C._Papa
# Hans_Vestberg
# Robert_Bakish
# Vittorio_Colao
# Herbert_Diess
# Bill_Hilf
# Bob_Chapek
# Stefano_Pessina
# Doug_McMillon
# Ann_Sarnoff
# Jason_Kilar
# Timothy_J._Sloan
# John_Mackey
# Laura_J._Alber
# Abidali_Neemuchwala
# Vince_McMahon
# Greg_Creed
# Rich_Barton

# %%
def to_space(x):
  return x.replace('_', ' ')

# Let's use *apply* to call a function over each element, returning a new Series
exec_df['name'].apply(to_space)
# Out:
# 0              Julie Sweet
# 1              Kumar Birla
# 2         Shantanu Narayen
# 3            Garo H. Armen
# 4          Guillaume Faury
#               ...
# 172         Laura J. Alber
# 173    Abidali Neemuchwala
# 174          Vince McMahon
# 175             Greg Creed
# 176            Rich Barton
# Name: name, Length: 177, dtype: object

# %%
# Let's use *apply* to call a function over each element, returning a new Series
exec_df['name'].apply(lambda x: x.replace('_', ' '))
# Out:
# 0              Julie Sweet
# 1              Kumar Birla
# 2         Shantanu Narayen
# 3            Garo H. Armen
# 4          Guillaume Faury
#               ...
# 172         Laura J. Alber
# 173    Abidali Neemuchwala
# 174          Vince McMahon
# 175             Greg Creed
# 176            Rich Barton
# Name: name, Length: 177, dtype: object

# %%
# I can also use *apply* to call a function over the rows of a dataframe
exec_df.apply(lambda x: x['name'].replace('_', ' '), axis=1)
# Out:
# 0              Julie Sweet
# 1              Kumar Birla
# 2         Shantanu Narayen
# 3            Garo H. Armen
# 4          Guillaume Faury
#               ...
# 172         Laura J. Alber
# 173    Abidali Neemuchwala
# 174          Vince McMahon
# 175             Greg Creed
# 176            Rich Barton
# Length: 177, dtype: object

# %%
# Let's clean the name by removing underscores...
exec_df['clean_name'] = exec_df['name'].apply(lambda x: x.replace('_', ' '))

exec_df
# Out:
#                     name  ...           clean_name
# 0            Julie_Sweet  ...          Julie Sweet
# 1            Kumar_Birla  ...          Kumar Birla
# 2       Shantanu_Narayen  ...     Shantanu Narayen
# 3          Garo_H._Armen  ...        Garo H. Armen
# 4        Guillaume_Faury  ...      Guillaume Faury
# ..                   ...  ...                  ...
# 172       Laura_J._Alber  ...       Laura J. Alber
# 173  Abidali_Neemuchwala  ...  Abidali Neemuchwala
# 174        Vince_McMahon  ...        Vince McMahon
# 175           Greg_Creed  ...           Greg Creed
# 176          Rich_Barton  ...          Rich Barton
#
# [177 rows x 4 columns]

# %%
exec_df.rename(columns={'name': 'old_name'})
# Out:
#                 old_name  ...           clean_name
# 0            Julie_Sweet  ...          Julie Sweet
# 1            Kumar_Birla  ...          Kumar Birla
# 2       Shantanu_Narayen  ...     Shantanu Narayen
# 3          Garo_H._Armen  ...        Garo H. Armen
# 4        Guillaume_Faury  ...      Guillaume Faury
# ..                   ...  ...                  ...
# 172       Laura_J._Alber  ...       Laura J. Alber
# 173  Abidali_Neemuchwala  ...  Abidali Neemuchwala
# 174        Vince_McMahon  ...        Vince McMahon
# 175           Greg_Creed  ...           Greg Creed
# 176          Rich_Barton  ...          Rich Barton
#
# [177 rows x 4 columns]

# %%
# We can do the same via SQL.  For the example we'll save the dataframe first...

exec_df.to_sql('temp_exec', conn, if_exists="replace")

pd.read_sql_query('select name, replace(name, "_", " ") as clean_name from temp_exec', conn)
# Out:
#                     name           clean_name
# 0            Julie_Sweet          Julie Sweet
# 1            Kumar_Birla          Kumar Birla
# 2       Shantanu_Narayen     Shantanu Narayen
# 3          Garo_H._Armen        Garo H. Armen
# 4        Guillaume_Faury      Guillaume Faury
# ..                   ...                  ...
# 172       Laura_J._Alber       Laura J. Alber
# 173  Abidali_Neemuchwala  Abidali Neemuchwala
# 174        Vince_McMahon        Vince McMahon
# 175           Greg_Creed           Greg Creed
# 176          Rich_Barton          Rich Barton
#
# [177 rows x 2 columns]

# %% [markdown]
# ## Selecting a subset of the rows

# %%
# Here's a column

exec_df['clean_name']
# Out:
# 0              Julie Sweet
# 1              Kumar Birla
# 2         Shantanu Narayen
# 3            Garo H. Armen
# 4          Guillaume Faury
#               ...
# 172         Laura J. Alber
# 173    Abidali Neemuchwala
# 174          Vince McMahon
# 175             Greg Creed
# 176            Rich Barton
# Name: clean_name, Length: 177, dtype: object

# %%
# We can apply a test (predicate) to each column, returning a Series of boolean true/false values

exec_df['clean_name'] == 'Julie Sweet'
# Out:
# 0       True
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 172    False
# 173    False
# 174    False
# 175    False
# 176    False
# Name: clean_name, Length: 177, dtype: bool

# %%
# If we compose these, we'll get only those rows where the boolean condition was True

exec_df[exec_df['clean_name'] == 'Julie Sweet']
# Out:
#           name                                       page born   clean_name
# 0  Julie_Sweet  https://en.wikipedia.org/wiki/Julie_Sweet  NaT  Julie Sweet

# %%
exec_df[exec_df['clean_name'] == 'Julie Sweet'][['page']]
# Out:
#                                         page
# 0  https://en.wikipedia.org/wiki/Julie_Sweet

# %%
# And in SQL...

exec_df.to_sql('temp_exec', conn, if_exists="replace")

pd.read_sql_query('select * from temp_exec where clean_name="Julie Sweet"', conn)
# Out:
#    index         name  ...  born   clean_name
# 0      0  Julie_Sweet  ...  None  Julie Sweet
#
# [1 rows x 5 columns]

# %%
pd.read_sql_query('select page from temp_exec where clean_name="Julie Sweet"', conn)
# Out:
#                                         page
# 0  https://en.wikipedia.org/wiki/Julie_Sweet

# %%
import numpy as np

exec_df.dropna(subset=['born'])
# Out:
#                  name  ...        clean_name
# 1         Kumar_Birla  ...       Kumar Birla
# 2    Shantanu_Narayen  ...  Shantanu Narayen
# 3       Garo_H._Armen  ...     Garo H. Armen
# 4     Guillaume_Faury  ...   Guillaume Faury
# 5        Daniel_Zhang  ...      Daniel Zhang
# ..                ...  ...               ...
# 165        Bob_Chapek  ...        Bob Chapek
# 166   Stefano_Pessina  ...   Stefano Pessina
# 167     Doug_McMillon  ...     Doug McMillon
# 169       Jason_Kilar  ...       Jason Kilar
# 174     Vince_McMahon  ...     Vince McMahon
#
# [97 rows x 4 columns]

# %%
pd.read_sql_query('select * from temp_exec where born is not null', conn).set_index('index')
# Out:
#                    name  ...        clean_name
# index                    ...
# 1           Kumar_Birla  ...       Kumar Birla
# 2      Shantanu_Narayen  ...  Shantanu Narayen
# 3         Garo_H._Armen  ...     Garo H. Armen
# 4       Guillaume_Faury  ...   Guillaume Faury
# 5          Daniel_Zhang  ...      Daniel Zhang
# ...                 ...  ...               ...
# 165          Bob_Chapek  ...        Bob Chapek
# 166     Stefano_Pessina  ...   Stefano Pessina
# 167       Doug_McMillon  ...     Doug McMillon
# 169         Jason_Kilar  ...       Jason Kilar
# 174       Vince_McMahon  ...     Vince McMahon
#
# [97 rows x 4 columns]

# %% [markdown]
# ## Joining Data
#
# We start with a simple join between company_ceos_df and exec_df and persist it to the database.  We then check how many companies did not have a match on CEO name.

# %%
exec_df[['clean_name', 'born']]
# Out:
#               clean_name       born
# 0            Julie Sweet        NaT
# 1            Kumar Birla 1967-06-14
# 2       Shantanu Narayen 1963-05-27
# 3          Garo H. Armen 1953-01-31
# 4        Guillaume Faury 1968-02-22
# ..                   ...        ...
# 172       Laura J. Alber        NaT
# 173  Abidali Neemuchwala        NaT
# 174        Vince McMahon 1945-08-24
# 175           Greg Creed        NaT
# 176          Rich Barton        NaT
#
# [177 rows x 2 columns]

# %%
company_ceos_df[['Executive', 'Company']]
# Out:
#                Executive                     Company
# 0            Julie Sweet                   Accenture
# 1            Kumar Birla          Aditya Birla Group
# 2       Shantanu Narayen               Adobe Systems
# 3          Garo H. Armen                      Agenus
# 4        Guillaume Faury                      Airbus
# ..                   ...                         ...
# 175       Laura J. Alber       Williams-Sonoma, Inc.
# 176  Abidali Neemuchwala  Wipro Technologies Limited
# 177        Vince McMahon                         WWE
# 178           Greg Creed                 Yum! Brands
# 179          Rich Barton                Zillow Group
#
# [180 rows x 2 columns]

# %%
company_ceos_df[['Executive', 'Company']].merge(exec_df[['clean_name', 'born']], 
                                                left_on=['Executive'], 
                                                right_on=['clean_name'])
# Out:
#                Executive  ...       born
# 0            Julie Sweet  ...        NaT
# 1            Kumar Birla  ... 1967-06-14
# 2       Shantanu Narayen  ... 1963-05-27
# 3          Garo H. Armen  ... 1953-01-31
# 4        Guillaume Faury  ... 1968-02-22
# ..                   ...  ...        ...
# 169       Laura J. Alber  ...        NaT
# 170  Abidali Neemuchwala  ...        NaT
# 171        Vince McMahon  ... 1945-08-24
# 172           Greg Creed  ...        NaT
# 173          Rich Barton  ...        NaT
#
# [174 rows x 4 columns]

# %%
company_ceos_df.to_sql('company_ceos', conn, if_exists="replace")
exec_df.to_sql('executives', conn, if_exists="replace")
company_data_df.to_sql('company_data', conn, if_exists='replace')

pd.read_sql_query('select Executive, Company, born from company_ceos ' +\
                  'join executives on Executive=clean_name ' +\
                  'where born is not null', conn)
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/core/generic.py:2615: UserWarning: The spaces in these column names will not be changed. In pandas versions < 0.14, spaces were converted to underscores.
#   method=method,
#            Executive                   Company                 born
# 0        Kumar Birla        Aditya Birla Group  1967-06-14 00:00:00
# 1   Shantanu Narayen             Adobe Systems  1963-05-27 00:00:00
# 2      Garo H. Armen                    Agenus  1953-01-31 00:00:00
# 3    Guillaume Faury                    Airbus  1968-02-22 00:00:00
# 4       Daniel Zhang                   Alibaba  1972-01-11 00:00:00
# ..               ...                       ...                  ...
# 91        Bob Chapek   The Walt Disney Company  1960-08-21 00:00:00
# 92   Stefano Pessina  Walgreens Boots Alliance  1941-06-04 00:00:00
# 93     Doug McMillon                  Wal-Mart  1966-10-17 00:00:00
# 94       Jason Kilar               WarnerMedia  1971-04-26 00:00:00
# 95     Vince McMahon                       WWE  1945-08-24 00:00:00
#
# [96 rows x 3 columns]

# %% [markdown]
# ###Finding the misses in the join.
#
# Note that the join above resulted in 174 rows.  However, there are more rows in company_ceos_df so we are missing some companies.  We can see which are missed using a left outer join; setting "indicator= True" allows us to see which tuples in company_ceos_df failed to find a match (left_only, e.g. row 24 and 172).

# %%
pd.set_option('display.max_rows', 200)
display(company_ceos_df[['Executive', 'Company']].merge(exec_df[['clean_name', 'born']], 
                                                left_on=['Executive'], 
                                                right_on=['clean_name'], how="left", indicator=True))
# Out:
#                           Executive  ...     _merge
# 0                       Julie Sweet  ...       both
# 1                       Kumar Birla  ...       both
# 2                  Shantanu Narayen  ...       both
# 3                     Garo H. Armen  ...       both
# 4                   Guillaume Faury  ...       both
# 5                      Daniel Zhang  ...       both
# 6                        Jeff Bezos  ...       both
# 7                           Lisa Su  ...       both
# 8                    Stephen Squeri  ...       both
# 9                       Doug Parker  ...       both
# 10                Joseph R. Swedish  ...       both
# 11                         Tim Cook  ...       both
# 12             Lakshmi Niwas Mittal  ...       both
# 13                     John Stankey  ...       both
# 14                 Charles Woodburn  ...       both
# 15                    Tapan Singhel  ...       both
# 16               Carlos Torres Vila  ...       both
# 17                   Brian Moynihan  ...       both
# 18                       Jes Staley  ...       both
# 19                   Warren Buffett  ...       both
# 20                      Hubert Joly  ...       both
# 21              Sunil Bharti Mittal  ...       both
# 22            Stephen A. Schwarzman  ...       both
# 23                 Andrew Mackenzie  ...       both
# 24                     Oliver zipse  ...  left_only
# 25                     Dave Calhoun  ...       both
# 26                      Rich Lesser  ...       both
# 27                       Bob Dudley  ...       both
# 28                  Denise Morrison  ...       both
# 29                Mark Shuttleworth  ...       both
# 30                    Paul Hermelin  ...       both
# 31                 Richard Fairbank  ...       both
# 32                      Jim Umpleby  ...       both
# 33                Evan G. Greenberg  ...       both
# 34                    Chuck Robbins  ...       both
# 35                   Michael Corbat  ...       both
# 36                    James Quincey  ...       both
# 37                  Brian Humphries  ...       both
# 38                 Brian L. Roberts  ...       both
# 39                    Tidjane Thiam  ...       both
# 40                James E. Thompson  ...       both
# 41                    Ola Källenius  ...  left_only
# 42                     Michael Dell  ...       both
# 43                 Christian Sewing  ...       both
# 44                      Frank Appel  ...       both
# 45                Roland Dickey Jr.  ...       both
# 46                  Edward D. Breen  ...       both
# 47                     G. V. Prasad  ...       both
# 48                      Jeff Clarke  ...       both
# 49                      Devin Wenig  ...       both
# 50                    Andrew Wilson  ...       both
# 51                     Börje Ekholm  ...  left_only
# 52                     Darren Woods  ...       both
# 53                 Carmine Di Sibio  ...       both
# 54                  Mark Zuckerberg  ...       both
# 55               Frederick W. Smith  ...       both
# 56                Sergio Marchionne  ...       both
# 57                  Abigail Johnson  ...       both
# 58                    James Hackett  ...       both
# 59                        Terry Gou  ...       both
# 60                  Lachlan Murdoch  ...       both
# 61                     Daymond John  ...       both
# 62                  Phebe Novakovic  ...       both
# 63             H. Lawrence Culp Jr.  ...       both
# 64                    Mary T. Barra  ...       both
# 65                    Emma Walmsley  ...       both
# 66                 David M. Solomon  ...       both
# 67                    Sundar Pichai  ...       both
# 68                     Felipe Gozon  ...       both
# 69   Gunupati Venkata Krishna Reddy  ...       both
# 70                    C Vijayakumar  ...       both
# 71                     Lee Shau Kee  ...       both
# 72                      Meg Whitman  ...       both
# 73                  Darius Adamczyk  ...       both
# 74                    John A. Kaneb  ...       both
# 75                       Noel Quinn  ...       both
# 76                   Arvind Krishna  ...       both
# 77                  Dikesh Malhotra  ...       both
# 78                     Salil Parekh  ...       both
# 79                   Robert H. Swan  ...       both
# 80                     Scott Etzler  ...       both
# 81                  Millard Drexler  ...       both
# 82               Richard B. Handler  ...       both
# 83                      James Dimon  ...       both
# 84                  Andrew S. Rosen  ...       both
# 85                    Pieter Elbers  ...       both
# 86                  Charles G. Koch  ...       both
# 87                      Robert Noel  ...       both
# 88                  Sheldon Adelson  ...       both
# 89                       Les Wexner  ...       both
# 90                  Marillyn Hewson  ...       both
# 91                       Steve Rowe  ...       both
# 92              Ajaypal Singh Banga  ...       both
# 93                Chris kempczinski  ...  left_only
# 94                    Kevin Sneader  ...       both
# 95                Jonathan Ornstein  ...       both
# 96              Steven A. Kandarian  ...       both
# 97                     Isaac Larian  ...       both
# 98                    Satya Nadella  ...       both
# 99                Michael J. Saylor  ...       both
# 100                 James P. Gorman  ...       both
# 101                      Toxey Haas  ...       both
# 102                     Chris Beard  ...       both
# 103                 Sumner Redstone  ...       both
# 104                      Jeff Shell  ...       both
# 105            Robert James Thomson  ...       both
# 106                   Mark Thompson  ...       both
# 107                Vijay K. Thadani  ...       both
# 108                     Mark Parker  ...       both
# 109                  Pekka Lundmark  ...       both
# 110               Vasant Narasimhan  ...       both
# 111               Tatsumi Kimishima  ...       both
# 112                   Tim Armstrong  ...       both
# 113                      Safra Catz  ...       both
# 114                       Mark Hurd  ...       both
# 115                  Ramon Laguarta  ...       both
# 116                        Ian Read  ...       both
# 117                  Patrice Louvet  ...       both
# 118                 David S. Taylor  ...       both
# 119                 John Strangfeld  ...       both
# 120                      Alan Joyce  ...       both
# 121                     Anil Ambani  ...       both
# 122                   Mukesh Ambani  ...       both
# 123                     Luca de Meo  ...       both
# 124                  Phiwa Nkambule  ...       both
# 125                  David I. McKay  ...       both
# 126                     Ross McEwan  ...       both
# 127                 Ben van Beurden  ...       both
# 128                 Michael O'Leary  ...  left_only
# 129             Douglas L. Peterson  ...       both
# 130        Herbert Fisk Johnson III  ...       both
# 131                    Brian Peddle  ...       both
# 132                    Oh-Hyun Kwon  ...       both
# 133                 Christian Klein  ...       both
# 134                 James Goodnight  ...       both
# 135            Jean-Pascal Tricoire  ...       both
# 136                      Joe Kaeser  ...       both
# 137                     David Simon  ...       both
# 138                 Chua Sock Koong  ...       both
# 139                   Masayoshi Son  ...       both
# 140                     Tony Aquila  ...       both
# 141                   Gary C. Kelly  ...       both
# 142              J. Clifford Hudson  ...       both
# 143                   Kevin Johnson  ...       both
# 144                    Raymond Kwok  ...       both
# 145                  Dilip Shanghvi  ...       both
# 146           William H. Rogers Jr.  ...       both
# 147                   Rakesh Khanna  ...       both
# 148                   Brian Cornell  ...       both
# 149               Rajesh Gopinathan  ...       both
# 150                    Li Dongsheng  ...       both
# 151                       Andy Penn  ...       both
# 152                        Ho Ching  ...       both
# 153                      Dave Lewis  ...       both
# 154                       Elon Musk  ...       both
# 155               Diego Della Valle  ...       both
# 156               Alan D. Schnitzer  ...       both
# 157                     Akio Toyoda  ...       both
# 158                  Bill Stromberg  ...       both
# 159                     Jack Dorsey  ...       both
# 160                     Oscar Munoz  ...       both
# 161                    ralph hamers  ...  left_only
# 162                  Joseph C. Papa  ...       both
# 163                   Hans Vestberg  ...       both
# 164                   Robert Bakish  ...       both
# 165                  Vittorio Colao  ...       both
# 166                   Herbert Diess  ...       both
# 167                       Bill Hilf  ...       both
# 168                      Bob Chapek  ...       both
# 169                 Stefano Pessina  ...       both
# 170                   Doug McMillon  ...       both
# 171                     Ann Sarnoff  ...       both
# 172                     Jason Kilar  ...       both
# 173                Timothy J. Sloan  ...       both
# 174                     John Mackey  ...       both
# 175                  Laura J. Alber  ...       both
# 176             Abidali Neemuchwala  ...       both
# 177                   Vince McMahon  ...       both
# 178                      Greg Creed  ...       both
# 179                     Rich Barton  ...       both
#
# [180 rows x 5 columns]

# %%
pd.set_option('display.max_rows', 50)
result_df = company_ceos_df[['Executive', 'Company']].merge(exec_df[['clean_name', 'born']], 
                                                left_on=['Executive'], 
                                                right_on=['clean_name'], how="outer", indicator=True)

result_df[result_df['_merge'] != 'both']
# Out:
#              Executive     Company          clean_name       born      _merge
# 24        Oliver zipse         BMW                 NaN        NaT   left_only
# 41       Ola Källenius  Daimler AG                 NaN        NaT   left_only
# 51        Börje Ekholm    Ericsson                 NaN        NaT   left_only
# 93   Chris kempczinski  McDonald's                 NaN        NaT   left_only
# 128    Michael O'Leary     Ryanair                 NaN        NaT   left_only
# 161       ralph hamers         UBS                 NaN        NaT   left_only
# 180                NaN         NaN  Ola K%C3%A4llenius 1969-06-11  right_only
# 181                NaN         NaN   B%C3%B6rje Ekholm        NaT  right_only
# 182                NaN         NaN   Michael O%27Leary        NaT  right_only

# %% [markdown]
# ## Composing Joins

# %%
pd.read_sql_query('select Executive, Company, born  from company_ceos ' +\
                  'join executives on Executive=clean_name join company_data cd on Company=cd.name ' +\
                  'where born is not null', conn)
# Out:
#                Executive                 Company                 born
# 0          Garo H. Armen                  Agenus  1953-01-31 00:00:00
# 1           Daniel Zhang                 Alibaba  1972-01-11 00:00:00
# 2       Brian L. Roberts                 Comcast  1959-06-28 00:00:00
# 3        Mark Zuckerberg                Facebook  1984-05-14 00:00:00
# 4          Sundar Pichai                  Google  1972-07-12 00:00:00
# 5        Darius Adamczyk               Honeywell  1966-02-08 00:00:00
# 6        Marillyn Hewson         Lockheed Martin  1953-12-27 00:00:00
# 7   Robert James Thomson               News Corp  1961-03-11 00:00:00
# 8             Joe Kaeser                 Siemens  1957-06-23 00:00:00
# 9            Jack Dorsey                 Twitter  1976-11-19 00:00:00
# 10         Hans Vestberg  Verizon Communications  1965-06-23 00:00:00

# %%
pd.read_sql_query('select * from company_ceos ' +\
                  'join executives on Executive=clean_name join company_data cd on Company=cd.name ' +\
                  'where born is not null', conn)
# Out:
#     index                 Company  ... first_funding_at last_funding_at
# 0       3                  Agenus  ...       04/08/2009      25/04/2013
# 1       5                 Alibaba  ...       01/10/1999      11/08/2005
# 2      38                 Comcast  ...       08/05/2013      08/05/2013
# 3      54                Facebook  ...       01/09/2004      21/01/2011
# 4      67                  Google  ...       01/08/1998      07/06/1999
# 5      73               Honeywell  ...       27/10/2009      27/10/2009
# 6      90         Lockheed Martin  ...       06/07/2009      22/11/2010
# 7     105               News Corp  ...       08/01/2010      08/01/2010
# 8     136                 Siemens  ...       19/07/2010      19/07/2010
# 9     159                 Twitter  ...       01/07/2007      08/09/2011
# 10    163  Verizon Communications  ...       26/01/2010      28/02/2014
#
# [11 rows x 33 columns]

# %%
company_ceos_df.merge(exec_df, 
                      left_on=['Executive'], 
                      right_on=['clean_name']).\
                      merge(company_data_df,
                            left_on='Company',
                            right_on='name')
# Out:
#                    Company  ... last_funding_at
# 0                   Agenus  ...      25/04/2013
# 1                  Alibaba  ...      11/08/2005
# 2              BAE Systems  ...      10/09/2010
# 3                  Comcast  ...      08/05/2013
# 4                     eBay  ...      01/06/1997
# 5                 Facebook  ...      21/01/2011
# 6         General Dynamics  ...      10/09/2010
# 7         General Electric  ...      19/11/2009
# 8                   Google  ...      07/06/1999
# 9                Honeywell  ...      27/10/2009
# 10         Lockheed Martin  ...      22/11/2010
# 11          Mesa Air Group  ...      13/08/2014
# 12               News Corp  ...      08/01/2010
# 13                 Siemens  ...      19/07/2010
# 14               Starbucks  ...      01/02/1991
# 15                   Tesco  ...      15/07/2010
# 16                 Twitter  ...      08/09/2011
# 17  Verizon Communications  ...      28/02/2014
#
# [18 rows x 30 columns]

# %% [markdown]
# # Lab 3 Part-II: Validating and Cleaning Data
#
# How do we know our data is good?  We can create rules that trigger when the data fails some particular set of **constraints**.

# %%
# Test with validation rules

replace_item = ''

failed = False
for name in exec_df['clean_name']:
  if not name.replace(' ', replace_item).\
          replace('.', replace_item).\
          replace('\'',replace_item).\
          replace('-',replace_item).isalpha():
    print ("Illegal name %s"%name)
    failed = True
    
if failed:
  print('Found illegal names!')
# Out:
# Illegal name Ola K%C3%A4llenius
# Illegal name B%C3%B6rje Ekholm
# Illegal name Michael O%27Leary
# Found illegal names!

# %% [markdown]
# ## Data Cleaning: Fixing the Errors
#
# One approach we could take is to realize that these are all strings in which accented characters are specially coded for use in (Wikipedia) URLs.  For instance, %C3 is a hex character code for an accented "u".  We can use a function called `unqote` to fix this...

# %%
from urllib.parse import unquote

exec_df['clean_name'].apply(unquote)
# Out:
# 0              Julie Sweet
# 1              Kumar Birla
# 2         Shantanu Narayen
# 3            Garo H. Armen
# 4          Guillaume Faury
#               ...
# 172         Laura J. Alber
# 173    Abidali Neemuchwala
# 174          Vince McMahon
# 175             Greg Creed
# 176            Rich Barton
# Name: clean_name, Length: 177, dtype: object

# %% [markdown]
# ## More Generally: Data Validation Tools
#
# Are there tools to help us validate data?  Of course!  We see an [example](https://validators.readthedocs.io/en/latest/) of one such tool, simply called `validators`, below.  There are many others in the data cleaning literature.

# %%
# !pip install validators
# Out:
# Collecting validators
#   Downloading https://files.pythonhosted.org/packages/db/2f/7fed3ee94ad665ad2c1de87f858f10a7785251ff75b4fd47987888d07ef1/validators-0.18.2-py3-none-any.whl
# Requirement already satisfied: decorator>=3.4.0 in /usr/local/lib/python3.6/dist-packages (from validators) (4.4.2)
# Requirement already satisfied: six>=1.4.0 in /usr/local/lib/python3.6/dist-packages (from validators) (1.15.0)
# Installing collected packages: validators
# Successfully installed validators-0.18.2

# %%
import validators.url

# Are all of the URLs valid?
exec_df['page'].apply(validators.url)
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
#        ...
# 172    True
# 173    True
# 174    True
# 175    True
# 176    True
# Name: page, Length: 177, dtype: bool

# %% [markdown]
# ## Validation against a master list
#
# We can also compare against "master" lists (in tables).  For example, company info about stock ticker symbols can be compared against the full list of symbols; states and countries can be compared against definitive lists.
#
# Suppose we want to confirm that `company_data_df` has valid country codes.

# %%
company_data_df[['name','country_code']]
# Out:
#                                 name country_code
# 0                           #waywire          USA
# 1                 &TV Communications          USA
# 2                  'Rock' Your Paper          EST
# 3                  (In)Touch Network          GBR
# 4                         +n (PlusN)          USA
# ...                              ...          ...
# 47753                          Zzish          GBR
# 47754  ZZNode Science and Technology          CHN
# 47755          Zzzzapp Wireless ltd.          HRV
# 47756                  [a]list games          NaN
# 47757                          [x+1]          USA
#
# [47758 rows x 2 columns]

# %% [markdown]
# TSome of these are NaNs -- let's drop them...

# %% [markdown]
# From someone's Github content, here's a nice list of all countries and region codes.

# %%
countries_df = pd.read_csv("https://raw.githubusercontent.com/lukes/ISO-3166-Countries-with-Regional-Codes/master/all/all.csv")

display(countries_df)
# Out:
#                   name alpha-2  ... sub-region-code  intermediate-region-code
# 0          Afghanistan      AF  ...            34.0                       NaN
# 1        Åland Islands      AX  ...           154.0                       NaN
# 2              Albania      AL  ...            39.0                       NaN
# 3              Algeria      DZ  ...            15.0                       NaN
# 4       American Samoa      AS  ...            61.0                       NaN
# ..                 ...     ...  ...             ...                       ...
# 244  Wallis and Futuna      WF  ...            61.0                       NaN
# 245     Western Sahara      EH  ...            15.0                       NaN
# 246              Yemen      YE  ...           145.0                       NaN
# 247             Zambia      ZM  ...           202.0                      14.0
# 248           Zimbabwe      ZW  ...           202.0                      14.0
#
# [249 rows x 11 columns]

# %%
validated = company_data_df.merge(countries_df, left_on=['country_code'], right_on=['alpha-3'],
                      how='left', indicator=True)

validated[validated['_merge'] != 'both']
# Out:
#                              permalink  ...     _merge
# 8                /organization/0-6-com  ...  left_only
# 19          /organization/1000-markets  ...  left_only
# 25              /organization/100du-tv  ...  left_only
# 30                 /organization/10sec  ...  left_only
# 35     /organization/115-network-disks  ...  left_only
# ...                                ...  ...        ...
# 47707               /organization/zura  ...  left_only
# 47712            /organization/zursh-2  ...  left_only
# 47729          /organization/zwoor-com  ...  left_only
# 47743              /organization/zympi  ...  left_only
# 47756       /organization/a-list-games  ...  left_only
#
# [5164 rows x 30 columns]

# %% [markdown]
# ## Record Linking: Working around the Errors
#
# Rather than figuring out how to clean these characters, we'll instead look at doing approximate matching.

# %% [markdown]
# Now we'll need to import some similarity matching code, to do approximate match between the original names and those returned by Wikipedia

# %%
# We are going to match the strings approximately, via "n-grams" or "q-grams" (sequences of n or q characters)
# Here it's five-grams

tok = sm.QgramTokenizer(qval=5,return_set=True)

# %%
# Now let's do a similarity join

# We'll reset the index, so there is a unique index field in the company_ceos_df dataframe
company_ceos_df.reset_index(inplace=True)

output_pairs = ssj.jaccard_join(company_ceos_df, exec_df, 'index', 'page', 'Executive', 'clean_name', tok, 0.35, 
                                l_out_attrs=['Executive'], r_out_attrs=['name'])

output_pairs[output_pairs['_sim_score'] < 1.0]
# Out:
# 0% [##############################] 100% | ETA: 00:00:00
# Total time elapsed: 00:00:00
#      _id  l_index  ...              r_name _sim_score
# 40    40       41  ...  Ola_K%C3%A4llenius   0.444444
# 50    50       51  ...   B%C3%B6rje_Ekholm   0.423077
# 126  126      128  ...   Michael_O%27Leary   0.538462
#
# [3 rows x 6 columns]

# %%
# At last! Company info + CEO info, together!

total = company_ceos_df.merge(output_pairs,left_on=['Executive'],right_on=['l_Executive']).\
        merge(exec_df,left_on=['r_page'],right_on=['page']).\
        merge(company_data_df, left_on='Company', right_on='name', how="left")

total
# Out:
#      index                     Company  ... first_funding_at last_funding_at
# 0        0                   Accenture  ...              NaN             NaN
# 1        1          Aditya Birla Group  ...              NaN             NaN
# 2        2               Adobe Systems  ...              NaN             NaN
# 3        3                      Agenus  ...       04/08/2009      25/04/2013
# 4        4                      Airbus  ...              NaN             NaN
# ..     ...                         ...  ...              ...             ...
# 172    175       Williams-Sonoma, Inc.  ...              NaN             NaN
# 173    176  Wipro Technologies Limited  ...              NaN             NaN
# 174    177                         WWE  ...              NaN             NaN
# 175    178                 Yum! Brands  ...              NaN             NaN
# 176    179                Zillow Group  ...              NaN             NaN
#
# [177 rows x 37 columns]

# %%
# Let's get ready to plot

# %matplotlib inline

# %%
total
# Out:
#      index                     Company  ... first_funding_at last_funding_at
# 0        0                   Accenture  ...              NaN             NaN
# 1        1          Aditya Birla Group  ...              NaN             NaN
# 2        2               Adobe Systems  ...              NaN             NaN
# 3        3                      Agenus  ...       04/08/2009      25/04/2013
# 4        4                      Airbus  ...              NaN             NaN
# ..     ...                         ...  ...              ...             ...
# 172    175       Williams-Sonoma, Inc.  ...              NaN             NaN
# 173    176  Wipro Technologies Limited  ...              NaN             NaN
# 174    177                         WWE  ...              NaN             NaN
# 175    178                 Yum! Brands  ...              NaN             NaN
# 176    179                Zillow Group  ...              NaN             NaN
#
# [177 rows x 37 columns]

# %% [markdown]
# ## Simple Analysis of Linked Data: Grouping and Analytics
#
# The `groupby` command allows us to coalesce data by groups.  In Pandas a Group is a special object with a set of rows.  We can see this with the `get_group` command.

# %%
total[['born','Company','Executive']].sort_values('born')
# Out:
#           born                     Company            Executive
# 101 1923-05-27         National Amusements      Sumner Redstone
# 70  1928-03-07  Henderson Land Development         Lee Shau Kee
# 19  1930-08-30          Berkshire Hathaway       Warren Buffett
# 87  1933-08-04             Las Vegas Sands      Sheldon Adelson
# 85  1935-11-01        Koch Industries Inc.      Charles G. Koch
# ..         ...                         ...                  ...
# 171        NaT          Whole Foods Market          John Mackey
# 172        NaT       Williams-Sonoma, Inc.       Laura J. Alber
# 173        NaT  Wipro Technologies Limited  Abidali Neemuchwala
# 175        NaT                 Yum! Brands           Greg Creed
# 176        NaT                Zillow Group          Rich Barton
#
# [177 rows x 3 columns]

# %% [markdown]
# We can apply computations, such as `count`, to the items in the group.  Values that are empty (NaN) do not count (no pun intended).

# %%
total.groupby(by='born').count()
# Out:
#             index  Company  ...  first_funding_at  last_funding_at
# born                        ...
# 1923-05-27      1        1  ...                 0                0
# 1928-03-07      1        1  ...                 0                0
# 1930-08-30      1        1  ...                 0                0
# 1933-08-04      1        1  ...                 0                0
# 1935-11-01      1        1  ...                 0                0
# ...           ...      ...  ...               ...              ...
# 1973-09-18      1        1  ...                 0                0
# 1976-11-19      1        1  ...                 1                1
# 1980-05-04      1        1  ...                 0                0
# 1984-05-14      1        1  ...                 1                1
# 1992-01-24      1        1  ...                 0                0
#
# [97 rows x 36 columns]

# %%
# We can do this in SQL too...

total.to_sql('total_info', conn, if_exists='replace', index=False)

# By default, SQL will include the Nan value (called NULL in SQL).  If we want to exclude it, 
# we need to include WHERE ... IS NOT NULL.

pd.read_sql('select born, count(Company) from total_info ' +\
            'where born is not null group by born', conn)
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/core/generic.py:2615: UserWarning: The spaces in these column names will not be changed. In pandas versions < 0.14, spaces were converted to underscores.
#   method=method,
#                    born  count(Company)
# 0   1923-05-27 00:00:00               1
# 1   1928-03-07 00:00:00               1
# 2   1930-08-30 00:00:00               1
# 3   1933-08-04 00:00:00               1
# 4   1935-11-01 00:00:00               1
# ..                  ...             ...
# 92  1973-09-18 00:00:00               1
# 93  1976-11-19 00:00:00               1
# 94  1980-05-04 00:00:00               1
# 95  1984-05-14 00:00:00               1
# 96  1992-01-24 00:00:00               1
#
# [97 rows x 2 columns]

# %%
# Let's look at when the CEOs were born

birthdays = total.groupby(by='born').count()[['Executive']]

birthdays
# Out:
#             Executive
# born
# 1923-05-27          1
# 1928-03-07          1
# 1930-08-30          1
# 1933-08-04          1
# 1935-11-01          1
# ...               ...
# 1973-09-18          1
# 1976-11-19          1
# 1980-05-04          1
# 1984-05-14          1
# 1992-01-24          1
#
# [97 rows x 1 columns]

# %% [markdown]
# We can actually use `resample` over dates, with a parameter, to group eg by decade (10 years, where A is the code for year):

# %%
birthdays.resample('10A').count().plot(kind='bar')

# %% [markdown]
# Maybe that's a little weird.  Can we do something more along the lines of what we expect, i.e., "1920s, 1930s, ..."?

# %%
# Get rid of the nulls!
bdays = total[['born']].dropna()

bdays = bdays.applymap(lambda bday: str(int(bday.year / 10) * 10) + 's')

bdays.reset_index().groupby('born').count().plot(kind='bar')

# %% [markdown]
# # To Do
#
# Is there a correlation between the kind of company and the age of the CEO?
#
# Does the company's line of business matter?

# %%
# total
# exec_df
# company_data_df
# company_ceos_df

company_ceos_df.merge(exec_df, left_on=['Executive'], right_on=['clean_name'])\
               .merge(company_data_df, left_on='Company', right_on='name')
# Out:
#     index                 Company  ... first_funding_at last_funding_at
# 0       3                  Agenus  ...       04/08/2009      25/04/2013
# 1       5                 Alibaba  ...       01/10/1999      11/08/2005
# 2      14             BAE Systems  ...       30/11/2009      10/09/2010
# 3      38                 Comcast  ...       08/05/2013      08/05/2013
# 4      49                    eBay  ...       01/06/1997      01/06/1997
# 5      54                Facebook  ...       01/09/2004      21/01/2011
# 6      62        General Dynamics  ...       05/08/2009      10/09/2010
# 7      63        General Electric  ...       19/11/2009      19/11/2009
# 8      67                  Google  ...       01/08/1998      07/06/1999
# 9      73               Honeywell  ...       27/10/2009      27/10/2009
# 10     90         Lockheed Martin  ...       06/07/2009      22/11/2010
# 11     95          Mesa Air Group  ...       13/08/2014      13/08/2014
# 12    105               News Corp  ...       08/01/2010      08/01/2010
# 13    136                 Siemens  ...       19/07/2010      19/07/2010
# 14    143               Starbucks  ...       01/02/1991      01/02/1991
# 15    153                   Tesco  ...       30/07/2009      15/07/2010
# 16    159                 Twitter  ...       01/07/2007      08/09/2011
# 17    163  Verizon Communications  ...       26/01/2010      28/02/2014
#
# [18 rows x 31 columns]
